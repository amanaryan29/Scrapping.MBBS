# %%
import bs4,webbrowser,requests
from bs4 import BeautifulSoup
import re
countnumb=0
dicts={}
sym=[]
comp=[]
def findword(url):
    s1=''
    count3=0
    try :
        requests.get(url).raise_for_status()
    except:
        return
    source_code=requests.get(url)
    plaintext=source_code.text
    soup=BeautifulSoup(plaintext,"lxml")
    for link in soup.findAll('div',{"id":"mainContent_area"}):
            for link1 in link.findAll('p'):
                if link1!=None:
                    s1=s1+' '+link1.text.strip()
                #print s1
            p1=s1.split(' ')
            return p1
               
    return None            
def getlinks(url):
    try :
        requests.get(url).raise_for_status()
    except:
        return
    source_code=requests.get(url)
    plaintext=source_code.text
    soup=BeautifulSoup(plaintext,"lxml")
    for link in soup.findAll('div',{"class":"module-content"}):
        for link2 in link.findAll('a'):
            if link2!=None:
                mylink=link2.get('href')
                global countnumb
                countnumb=countnumb+1
                print(mylink)
                countsym=0
                countcomp=0
                counting=[]
                tex=findword(mylink)
                if tex!=None:
                    for p in sym:
                        if p in tex or p+'.' in tex or p+',' in tex: 
                            countsym+=1
                    for p in comp:
                        if p in tex or p+'.' in tex or p+',' in tex:
                            countcomp+=1
                counting.append(countsym)
                counting.append(countcomp)
                counting.append(countnumb)
                countings=tuple(counting)
                dicts[countings]=mylink
    for link in soup.findAll('div',{"class":"results-container"}):
        for link2 in link.findAll('a'):
            if link2!=None:
                mylink=link2.get('href')
                print(mylink)
                countnumb=countnumb+1
                countsym=0
                countcomp=0
                counting=[]
                tex=findword(mylink)
                if tex!=None:
                    for p in sym:
                        if p in tex or p+'.' in tex or p+',' in tex: 
                            countsym+=1
                    for p in comp:
                        if p in tex or p+'.' in tex or p+',' in tex:
                            countcomp+=1
                counting.append(countsym)
                counting.append(countcomp)
                counting.append(countnumb)
                countings=tuple(counting)
                dicts[countings]=mylink
    
    
lis=[2,'asthma','bronchitis',3,'fever','nausea','coughing',2,'smoking','obesity']
sz=len(lis)
count1=lis[0]
link1=''
for i in range(1,(count1+1)):
    link1=link1+lis[i]+'%20'
count2=lis[count1+1]
countt=count1+2+count2 #End of sym
count3=lis[countt]
global sym
global comp
for i in range(count1+2,countt):
    sym.append(lis[i])
for i in range(countt+1,sz):
    comp.append(lis[i])

for l in range(1,2):
    newlink='http://www.webmd.com/search/2/results?query='+link1+'&page='+str(l)
    print (newlink+"\n")
    getlinks(newlink)
    print('\n')
# Out:
# http://www.webmd.com/search/2/results?query=asthma%20bronchitis%20&page=1
#
# http://www.webmd.com/asthma/default.htm
# /asthma/guide/asthma-overview-facts
# /asthma/guide/asthma_causes_prevention
# /asthma/guide/asthma-symptoms-types
# /asthma/guide/asthma-diagnosis-test
# /asthma/guide/asthma-treatment-care
# /asthma/guide/asthma-living-managing
# /asthma/guide/asthma-support-resources
# http://www.webmd.com/lung/ss/slideshow-bronchitis-overview
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\Users\ragha\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      62             except LookupError as e:
# ---> 63                 try: root = nltk.data.find('corpora/%s' % zip_name)
#      64                 except LookupError: raise e
#
# C:\Users\ragha\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     640     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 641     raise LookupError(resource_not_found)
#     642
#
# LookupError:
# **********************************************************************
#   Resource 'corpora/wordnet.zip/wordnet/' not found.  Please use
#   the NLTK Downloader to obtain the resource:  >>> nltk.download()
#   Searched in:
#     - 'C:\\Users\\ragha/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'C:\\Users\\ragha\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\ragha\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\ragha\\AppData\\Roaming\\nltk_data'
# **********************************************************************
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-4-cf77f318f056> in <module>()
#     104     newlink='http://www.webmd.com/search/2/results?query='+link1+'&page='+str(l)
#     105     print (newlink+"\n")
# --> 106     getlinks(newlink)
#     107     print('\n')
#
# <ipython-input-4-cf77f318f056> in getlinks(url)
#      46                 if tex!=None:
#      47                     for i in tex:
# ---> 48                         tex1=lemmatizer.lemmatize(i)
#      49                     tex=tex1
#      50                     for p in sym:
#
# C:\Users\ragha\Anaconda3\lib\site-packages\nltk\stem\wordnet.py in lemmatize(self, word, pos)
#      38
#      39     def lemmatize(self, word, pos=NOUN):
# ---> 40         lemmas = wordnet._morphy(word, pos)
#      41         return min(lemmas, key=len) if lemmas else word
#      42
#
# C:\Users\ragha\Anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#      97             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#      98
# ---> 99         self.__load()
#     100         # This looks circular, but its not, since __load() changes our
#     101         # __class__ to something new:
#
# C:\Users\ragha\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      62             except LookupError as e:
#      63                 try: root = nltk.data.find('corpora/%s' % zip_name)
# ---> 64                 except LookupError: raise e
#      65
#      66         # Load the corpus.
#
# C:\Users\ragha\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      59         else:
#      60             try:
# ---> 61                 root = nltk.data.find('corpora/%s' % self.__name)
#      62             except LookupError as e:
#      63                 try: root = nltk.data.find('corpora/%s' % zip_name)
#
# C:\Users\ragha\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     639     sep = '*' * 70
#     640     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 641     raise LookupError(resource_not_found)
#     642
#     643
#
# LookupError:
# **********************************************************************
#   Resource 'corpora/wordnet' not found.  Please use the NLTK
#   Downloader to obtain the resource:  >>> nltk.download()
#   Searched in:
#     - 'C:\\Users\\ragha/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - 'C:\\Users\\ragha\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\ragha\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\ragha\\AppData\\Roaming\\nltk_data'
# **********************************************************************

# %%
import bs4,webbrowser,requests
from bs4 import BeautifulSoup
import re
def findword1(url):
    s1=''
    p1=''
    count3=0
    try :
        requests.get(url).raise_for_status()
    except:
        return
       #print ('Hello')
    source_code=requests.get(url)
    plaintext=source_code.text
    soup=BeautifulSoup(plaintext,"lxml")
    for link in soup.findAll('div',{"class":"mSyndicate"}):
            #print link 
            for link1 in link.findAll('p'):
                if link1!=None:
                    s1=s1+' '+link1.text.strip()
                #print s1
            p1=s1.split(' ')
               
    if p1!='':
        return p1
    else:
        return None           
def getlinks1(url):
    try :
        requests.get(url).raise_for_status()
    except:
        return
    source_code=requests.get(url)
    plaintext=source_code.text
    soup=BeautifulSoup(plaintext,"lxml")
    for link in soup.findAll('div',{"id":"results"}):
        for link2 in link.findAll('a'):
            if link2!=None:
                mylink=link2.get('href')
                global countnumb
                countnumb=countnumb+1
                print(mylink)
                countsym=0
                countcomp=0
                counting=[]
                tex=findword1(mylink)
                if tex!=None:
                    for p in sym:
                        if p in tex or p+'.' in tex or p+',' in tex: 
                            countsym+=1
                    for p in comp:
                        if p in tex or p+'.' in tex or p+',' in tex:
                            countcomp+=1
                counting.append(countsym)
                counting.append(countcomp)
                counting.append(countnumb)
                countings=tuple(counting)
                dicts[countings]=mylink    
    
link1=''
for i in range(1,(count1+1)):
    if i!=count1:
        link1=link1+lis[i]+'%2B'
    else:
        link1+=lis[i]
for l in range(1,2):
    #https://search.cdc.gov/search?affiliate=cdc-main&commit=Search&page=1&query=asthma%2Bbronchitis%2B
    newlink='https://search.cdc.gov/search?utf8=%E2%9C%93&affiliate=cdc-main&page='+str(l)+'&query='+link1
    print newlink+"\n"
    getlinks1(newlink)
    print('\n')
# Out:
# https://search.cdc.gov/search?utf8=%E2%9C%93&affiliate=cdc-main&page=1&query=asthma%2Bbronchitis
#
# https://www.cdc.gov/asthma/actionplan.html
# https://www.cdc.gov/nchs/fastats/copd.htm
# https://www.cdc.gov/flu/asthma/index.htm
# https://www.cdc.gov/childrensmentalhealth/index.html
# https://www.cdc.gov/air/ozone.html
# https://www.cdc.gov/mmwr/preview/mmwrhtml/mm6216a3.htm
# https://www.cdc.gov/climateandhealth/effects/wildfires.htm
# https://www.cdc.gov/nchs/data/ad/ad123acc.pdf
# https://www.cdc.gov/nceh/ehhe/trailerstudy/pdfs/08_118152_new-resident-flyer-final-032508.pdf
# https://www.cdc.gov/mmwr/preview/mmwrhtml/su5401a36.htm
# https://www.cdc.gov/climateandhealth/pubs/precip-final_508.pdf
# https://www.cdc.gov/h1n1flu/disabilities/5_things_caregivers_people_disability.htm
# https://www.cdc.gov/mmwr/preview/mmwrhtml/mm5616a2.htm
# http://stacks.cdc.gov/view/cdc/8010/
# https://www.cdc.gov/niosh/hhe/reports/pdfs/2006-0059-3009.pdf
# https://www.cdc.gov/features/pneumonia/index.html
# https://www.cdc.gov/niosh/hhe/reports/pdfs/1992-0122-2570.pdf
# https://www.cdc.gov/mmwr/volumes/65/wr/pdfs/mm6545a1.pdf
# https://www.cdc.gov/nceh/drywall/docs/WhatYouShouldKnowaboutFormaldehyde.pdf
# http://www.cdc.gov/niosh/nioshtic-2/20045461.html

# %%
import bs4,webbrowser,requests
from bs4 import BeautifulSoup
import re
def findword2(url):
    s1=''
    p1=''
    count3=0
    try :
        requests.get(url).raise_for_status()
    except:
        return
       #print ('Hello')
    source_code=requests.get(url)
    plaintext=source_code.text
    soup=BeautifulSoup(plaintext,"lxml")
    for link in soup.findAll('div',{"class":"row inner_content"}):
            #print link 
            for link1 in link.findAll('p'):
                if link1!=None:
                    s1=s1+' '+link1.text.strip()
                #print s1
            p1=s1.split(' ')
               
    if p1!='':
       
        return p1
    else:
        for link in soup.findAll('div',{"class":"field field-name-body field-type-text-with-summary field-label-hidden"}):
            #print link 
            for link1 in link.findAll('p'):
                if link1!=None:
                    s1=s1+' '+link1.text.strip()
                #print s1
            p1=s1.split(' ')
    if p1!='':
        return p1
    else:
        return None   
def getlinks2(url):
    try :
        requests.get(url).raise_for_status()
    except:
        return
    source_code=requests.get(url)
    plaintext=source_code.text
    soup=BeautifulSoup(plaintext,"lxml")
    for link in soup.findAll('div',{"id":"results"}):
        for link2 in link.findAll('a'):
            if link2!=None:
                mylink=link2.get('href')
                global countnumb
                countnumb=countnumb+1
                print(mylink)
                countsym=0
                countcomp=0
                counting=[]
                tex=findword2(mylink)
                if tex!=None:
                    for p in sym:
                        if p in tex or p+'.' in tex or p+',' in tex: 
                            countsym+=1
                    for p in comp:
                        if p in tex or p+'.' in tex or p+',' in tex:
                            countcomp+=1
                counting.append(countsym)
                counting.append(countcomp)
                counting.append(countnumb)
                countings=tuple(counting)
                dicts[countings]=mylink    
    
link1=''
for i in range(1,(count1+1)):
    if i!=count1:
        link1=link1+lis[i]+'%2B'
    else:
        link1+=lis[i]
for l in range(1,2):
    newlink='https://search.nih.gov/search?affiliate=nih&commit=Search&page='+str(l)+'&query='+link1
    print newlink+"\n"
    getlinks2(newlink)
    print('\n')
# Out:
# https://search.nih.gov/search?affiliate=nih&commit=Search&page=1&query=asthma%2Bbronchitis
#
# https://www.nhlbi.nih.gov/health/health-topics/topics/asthma/
# https://www.ncbi.nlm.nih.gov/pubmed/26466493
# https://www.nhlbi.nih.gov/health/health-topics/topics/hlw/
# https://dailymed.nlm.nih.gov/dailymed/lookup.cfm?setid=10816e9d-0c53-424b-b482-fdd01a4d8525
# https://www.nhlbi.nih.gov/health/health-topics/topics/brnchi/treatment
# https://www.ncbi.nlm.nih.gov/pubmed/3964740/
# http://www.nhlbi.nih.gov/health/health-topics/topics/brnchi/signs
# https://www.ncbi.nlm.nih.gov/pubmed/13952928
# https://www.nhlbi.nih.gov/health/health-topics/topics/hlw/condition
# https://www.ncbi.nlm.nih.gov/pubmed/3794612
# https://www.ncbi.nlm.nih.gov/pubmed/14294167
# https://www.ncbi.nlm.nih.gov/pubmedhealth/PMH0001153/
# https://www.ncbi.nlm.nih.gov/pubmedhealth/PMHT0000084/
# https://www.ncbi.nlm.nih.gov/pubmed/4663848
# https://www.ncbi.nlm.nih.gov/pubmed/1556541
# https://www.ncbi.nlm.nih.gov/pubmed/4397135
# https://www.ncbi.nlm.nih.gov/pubmed/14293391
# https://www.ncbi.nlm.nih.gov/pubmed/4758567
# https://www.ncbi.nlm.nih.gov/pubmed/13613142
# https://www.ncbi.nlm.nih.gov/pubmed/14449964

# %%
print dicts
# Out:
# {(0, 0, 66): 'https://www.nhlbi.nih.gov/health/health-topics/topics/hlw/', (1, 0, 22): 'https://www.cdc.gov/features/pneumonia/index.html', (0, 0, 45): 'https://www.ncbi.nlm.nih.gov/pubmed/26466493', (0, 0, 8): 'https://www.cdc.gov/air/ozone.html', (0, 0, 64): 'https://www.nhlbi.nih.gov/health/health-topics/topics/asthma/', (0, 0, 43): 'http://www.cdc.gov/niosh/nioshtic-2/20045461.html', (0, 0, 22): 'http://www.webmd.com/asthma/understanding-wheezing-symptoms', (0, 0, 78): 'https://www.ncbi.nlm.nih.gov/pubmed/1556541', (0, 0, 41): 'https://www.cdc.gov/mmwr/volumes/65/wr/pdfs/mm6545a1.pdf', (0, 0, 20): 'https://www.cdc.gov/niosh/nioshtic-2/20028275.html', (0, 0, 76): 'https://www.ncbi.nlm.nih.gov/pubmedhealth/PMHT0000084/', (0, 0, 55): 'https://www.ncbi.nlm.nih.gov/pubmedhealth/PMH0001153/', (0, 0, 18): 'https://www.cdc.gov/mmwr/preview/mmwrhtml/su5401a36.htm', (0, 0, 74): 'https://www.nhlbi.nih.gov/health/health-topics/topics/hlw
# %%
import bs4,webbrowser,requests
from bs4 import BeautifulSoup
import re
def findword3(url):
    #print url
    s1=''
    p1=''
    count3=0
    try :
        requests.get(url).raise_for_status()
    except:
        return
    # print ('Hello')
    source_code=requests.get(url)
    plaintext=source_code.text
#    print plaintext
    soup=BeautifulSoup(plaintext,"lxml")
    for link in soup.findAll('div',{"class":"content"}):
            #print link 
            for link1 in link.findAll('p'):
                if link1!=None:
                    s1=s1+' '+link1.text.strip()
                #print s1
            p1=s1.split(' ')
               
    if p1!='':
        return p1
    else:
        return None   
def getlinks3(url):
    try :
        requests.get(url).raise_for_status()
    except:
        return
    #print ('hello')
    source_code=requests.get(url)
    plaintext=source_code.text
    soup=BeautifulSoup(plaintext,"lxml")
    for link in soup.findAll('div',{"class":"results"}):
        # print link
        for link2 in link.findAll('a'):
            if link2!=None:
                mylink=link2.get('href')
                global countnumb
                countnumb=countnumb+1
                print(mylink)
                countsym=0
                countcomp=0
                counting=[]
                tex=findword3(mylink)
                if tex!=None:
                    for p in sym:
                        if p in tex or p+'.' in tex or p+',' in tex: 
                            countsym+=1
                    for p in comp:
                        if p in tex or p+'.' in tex or p+',' in tex:
                            countcomp+=1
                counting.append(countsym)
                counting.append(countcomp)
                counting.append(countnumb)
                countings=tuple(counting)
                dicts[countings]=mylink    
    
link1=''
for i in range(1,(count1+1)):
    if i!=count1:
        link1=link1+lis[i]+'%2B'
    else:
        link1+=lis[i]
for l in range(1,2):
    #http://www.healthline.com/search?q1=asthma%2Bbronchitis
    #http://www.mayoclinic.org/search/search-results?q=asthma+bronchitis
    #http://www.mayoclinic.org/search/search-results?q=asthma+bronchitis&Page=2&cItems=10
    newlink='http://www.mayoclinic.org/search/search-results?q='+link1+'&Page='+str(l)+'&cItems=10'
    print newlink+"\n"
    getlinks3(newlink)
    print('\n')
# Out:
# http://www.mayoclinic.org/search/search-results?q=asthma%2Bbronchitis&Page=1&cItems=10
#
# http://www.mayoclinic.org/diseases-conditions/chronic-cough/symptoms-causes/dxc-20201783
# http://www.mayoclinic.org/diseases-conditions/chronic-cough/symptoms-causes/dxc-20201783
# http://www.mayoclinic.org/diseases-conditions/bronchitis/expert-answers/acute-bronchitis/faq-20057839
# http://www.mayoclinic.org/diseases-conditions/bronchitis/expert-answers/acute-bronchitis/faq-20057839
# http://www.mayoclinic.org/diseases-conditions/asthma/basics/treatment/con-20026992
# http://www.mayoclinic.org/diseases-conditions/asthma/basics/treatment/con-20026992
# http://www.mayoclinic.org/diseases-conditions/childhood-asthma/symptoms-causes/dxc-20193101
# http://www.mayoclinic.org/diseases-conditions/childhood-asthma/symptoms-causes/dxc-20193101
# http://www.mayoclinic.org/drugs-supplements/beta-2-adrenergic-agonist-oral-route-injection-route/proper-use/drg-20069364
# http://www.mayoclinic.org/drugs-supplements/beta-2-adrenergic-agonist-oral-route-injection-route/proper-use/drg-20069364
# http://www.mayoclinic.org/diseases-conditions/occupational-asthma/basics/treatment/con-20032379
# http://www.mayoclinic.org/diseases-conditions/occupational-asthma/basics/treatment/con-20032379
# http://www.mayoclinic.org/diseases-conditions/asthma/expert-answers/trouble-breathing/faq-20057865
# http://www.mayoclinic.org/diseases-conditions/asthma/expert-answers/trouble-breathing/faq-20057865
# http://www.mayoclinic.org/diseases-conditions/childhood-asthma/diagnosis-treatment/treatment/txc-20193128
# http://www.mayoclinic.org/diseases-conditions/childhood-asthma/diagnosis-treatment/treatment/txc-20193128
# http://www.mayoclinic.org/diseases-conditions/bronchitis/basics/treatment/con-20014956
# http://www.mayoclinic.org/diseases-conditions/bronchitis/basics/treatment/con-20014956
# http://www.mayoclinic.org/diseases-conditions/bronchitis/basics/tests-diagnosis/con-20014956
# http://www.mayoclinic.org/diseases-conditions/bronchitis/basics/tests-diagnosis/con-20014956
# http://www.mayoclinic.org/search/search-results?q=asthma%2bbronchitis&Page=1&cItems=10
# http://www.mayoclinic.org/search/search-results?q=asthma%2bbronchitis&Page=2&cItems=10
# http://www.mayoclinic.org/search/search-results?q=asthma%2bbronchitis&Page=3&cItems=10
# http://www.mayoclinic.org/search/search-results?q=asthma%2bbronchitis&Page=4&cItems=10
# http://www.mayoclinic.org/search/search-results?q=asthma%2bbronchitis&Page=5&cItems=10
# http://www.mayoclinic.org/search/search-results?q=asthma%2bbronchitis&Page=2&cItems=10

# %%
keylist = dicts.keys()
keylist.sort(reverse=True)
dicts1={}
count2=0
for key in keylist:
    print str(key)+" "+dicts[key]
    count2=count2+1
    if count2==5:
        break
# Out:
# (2, 0, 90) http://www.nhlbi.nih.gov/health/health-topics/topics/brnchi/signs
# (2, 0, 27) http://www.webmd.com/lung/cold-becomes-bronchitis
# (2, 0, 23) http://www.webmd.com/lung/is-bronchitis-contagious
# (2, 0, 18) http://www.webmd.com/lung/cold-becomes-bronchitis
# (2, 0, 14) http://www.webmd.com/lung/is-bronchitis-contagious

# %%
print dicts
# Out:
# {(0, 0, 103): 'https://www.ncbi.nlm.nih.gov/pubmed/14449964', (0, 0, 208): 'http://www.mayoclinic.org/diseases-conditions/occupational-asthma/basics/treatment/con-20032379', (0, 0, 66): 'https://www.nhlbi.nih.gov/health/health-topics/topics/hlw/', (1, 0, 22): 'https://www.cdc.gov/features/pneumonia/index.html', (1, 0, 131): 'http://www.mayoclinic.org/diseases-conditions/chronic-cough/symptoms-causes/dxc-20201783', (0, 0, 45): 'https://www.ncbi.nlm.nih.gov/pubmed/26466493', (0, 0, 8): 'https://www.cdc.gov/air/ozone.html', (0, 0, 101): 'https://www.ncbi.nlm.nih.gov/pubmed/4758567', (0, 0, 222): 'http://www.mayoclinic.org/search/search-results?q=asthma%2bbronchitis&Page=5&cItems=10', (0, 0, 64): 'https://www.nhlbi.nih.gov/health/health-topics/topics/asthma/', (0, 0, 185): 'http://www.mayoclinic.org/diseases-conditions/bronchitis/expert-answers/acute-bronchitis/faq-20057839', (0, 0, 43): 'http://www.cdc.gov/niosh/nioshtic-2/20045461.html', (0, 0, 22): 'http://www.webmd.com/asthma/understanding-wheezing-symptoms', (0, 0, 99): 'https://www.ncbi.nlm.nih.gov/pubmed/4397135', (0, 0, 220): 'http://www.mayoclinic.org/search/search-results?q=asthma%2bbronchitis&Page